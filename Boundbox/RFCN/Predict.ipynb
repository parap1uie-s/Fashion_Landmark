# %%
from Train_Landmark import *
# Out:
# d:\program files\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import os
import matplotlib.patches as patches

% matplotlib inline

# %%
dataset_val = FashionDataset()
dataset_val.initDB(100, start=30000)
dataset_val.prepare()

# %%
def get_ax(rows=1, cols=1, size=8):
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
Img = dataset_val.load_image(1)
bbox,label = dataset_val.load_bbox(1)
print(Img.shape)
# Out:
# (512, 512, 3)

# %%
plt.clf()
(y1, x1, y2, x2) = bbox[0]
p = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=2,
                      alpha=0.7, linestyle="dashed",
                      edgecolor="red", facecolor='none')
ax = get_ax(1)
ax.add_patch(p)
ax.imshow(Img)
